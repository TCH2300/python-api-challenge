# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %%
cities
# Out:
# ['coracao de jesus',
#  'hithadhoo',
#  'mar del plata',
#  'ponta do sol',
#  'port alfred',
#  'vila velha',
#  'batagay',
#  'shaunavon',
#  'omsukchan',
#  'port lincoln',
#  'clyde river',
#  'hermanus',
#  'kapaa',
#  'hobart',
#  'hirado',
#  'mahebourg',
#  'saldanha',
#  'rikitea',
#  'port elizabeth',
#  'chifeng',
#  'souillac',
#  'castro',
#  'brae',
#  'jamestown',
#  'tasiilaq',
#  'cisternino',
#  'severo-kurilsk',
#  'torbay',
#  'missoula',
#  'bluff',
#  'thompson',
#  'vaini',
#  'karatsu',
#  'lata',
#  'camopi',
#  'east london',
#  'victoria',
#  'talnakh',
#  'punta arenas',
#  'mehran',
#  'los llanos de aridane',
#  'sungaipenuh',
#  'bredasdorp',
#  'lazaro cardenas',
#  'saint-philippe',
#  'attawapiskat',
#  'sistranda',
#  'bambous virieux',
#  'barrow',
#  'ushuaia',
#  'ocampo',
#  'atlantic beach',
#  'mys shmidta',
#  'atuona',
#  'the valley',
#  'taoudenni',
#  'mandalgovi',
#  'albany',
#  'nazareno',
#  'cockburn town',
#  'barranca',
#  'san cristobal',
#  'mount gambier',
#  'yulara',
#  'norman wells',
#  'hilo',
#  'kaitangata',
#  'bay roberts',
#  'waipawa',
#  'belushya guba',
#  'avarua',
#  'busselton',
#  'letlhakane',
#  'yellowknife',
#  'hami',
#  'port macquarie',
#  'masunga',
#  'puerto ayora',
#  'kieta',
#  'amderma',
#  'kilakarai',
#  'ribeira grande',
#  'la rioja',
#  'hobyo',
#  'te anau',
#  'vila franca do campo',
#  'kitimat',
#  'kosh-agach',
#  'grand river south east',
#  'new norfolk',
#  'oudtshoorn',
#  'vanimo',
#  'dudinka',
#  'constitucion',
#  'odesskoye',
#  'coquimbo',
#  'bandarbeyla',
#  'santa cruz de la palma',
#  'siyabuswa',
#  'curitibanos',
#  'tuatapere',
#  'bethel',
#  'mehamn',
#  'syracuse',
#  'nanortalik',
#  'kodiak',
#  'saint anthony',
#  'utete',
#  'klaksvik',
#  'canto do buriti',
#  'novaya igirma',
#  'elblag',
#  'koroni',
#  'roald',
#  'saint-pierre',
#  'san luis',
#  'qaanaaq',
#  'mataura',
#  'opuwo',
#  'cabo san lucas',
#  'fortuna',
#  'ohara',
#  'san patricio',
#  'bontang',
#  'kumba',
#  'palabuhanratu',
#  'vao',
#  'turochak',
#  'tuktoyaktuk',
#  'digha',
#  'illoqqortoormiut',
#  'tsabong',
#  'neuquen',
#  'diapaga',
#  'marcona',
#  'lulea',
#  'kyabe',
#  'isangel',
#  'quatre cocos',
#  'manavalakurichi',
#  'daoukro',
#  'carnarvon',
#  'mayahi',
#  'tirlyanskiy',
#  'lompoc',
#  'laguna',
#  'arraial do cabo',
#  'pevek',
#  'khatanga',
#  'galiwinku',
#  'margate',
#  'lufilufi',
#  'lamu',
#  'talas',
#  'deputatskiy',
#  'provideniya',
#  'taolanaro',
#  'kuche',
#  'dingzhou',
#  'shirwal',
#  'karaul',
#  'kavieng',
#  'palmer',
#  'tsihombe',
#  'turbat',
#  'corn island',
#  'den helder',
#  'calabozo',
#  'pimentel',
#  'cape town',
#  'barentsburg',
#  'dujuma',
#  'malakal',
#  'general roca',
#  'temaraia',
#  'teluk nibung',
#  'dikson',
#  'sao joao da barra',
#  'kununurra',
#  'dingle',
#  'sitka',
#  'saskylakh',
#  'henties bay',
#  'hasaki',
#  'grindavik',
#  'airai',
#  'meyungs',
#  'erenhot',
#  'grand gaube',
#  'marsabit',
#  'vaitupu',
#  'blytheville',
#  'nikolskoye',
#  'warqla',
#  'charters towers',
#  'longyearbyen',
#  'pascagoula',
#  'ulladulla',
#  'ribeira brava',
#  'luderitz',
#  'lagoa',
#  'idritsa',
#  'kerman',
#  'roma',
#  'yuli',
#  'lorengau',
#  'praya',
#  'balabac',
#  'mykhaylivka',
#  'ambon',
#  'hualmay',
#  'bur gabo',
#  'dakar',
#  'nizhneyansk',
#  'glendive',
#  'paamiut',
#  'bucerias',
#  'sinnamary',
#  'ternate',
#  'touros',
#  'hofn',
#  'olavarria',
#  'hambantota',
#  'ballina',
#  'cherskiy',
#  'butaritari',
#  'saint-francois',
#  'estevan',
#  'saint-augustin',
#  'zhangjiakou',
#  'komsomolskiy',
#  'barbacena',
#  'ostrovnoy',
#  'yumen',
#  'basco',
#  'trinidad',
#  'sinjar',
#  'gura teghii',
#  'qaqortoq',
#  'meiganga',
#  'comodoro rivadavia',
#  'abu samrah',
#  'anadyr',
#  'bengkulu',
#  'mangai',
#  'pangai',
#  'kurchum',
#  'asau',
#  'maputo',
#  'bilma',
#  'sisimiut',
#  'lima',
#  'gilgit',
#  'evensk',
#  'suicheng',
#  'samusu',
#  'minab',
#  'chuzhou',
#  'husavik',
#  'sentyabrskiy',
#  'rolim de moura',
#  'rio grande',
#  'saleaula',
#  'yeppoon',
#  'tumannyy',
#  'sao filipe',
#  'antalaha',
#  'najran',
#  'iwanai',
#  'georgetown',
#  'portland',
#  'pizhma',
#  'road town',
#  'ocotepec',
#  'adrar',
#  'upernavik',
#  'lebu',
#  'dodge city',
#  'yarmouth',
#  'katsiveli',
#  'nizhniy tsasuchey',
#  'afgoye',
#  'kenai',
#  'tiksi',
#  'emerald',
#  'fort-shevchenko',
#  'abu dhabi',
#  'avera',
#  'thunder bay',
#  'ancud',
#  'yangjiang',
#  'santa marta',
#  'yar-sale',
#  'nchelenge',
#  'micheweni',
#  'vostok',
#  'viligili',
#  'port hawkesbury',
#  'esperance',
#  'port-gentil',
#  'maarianhamina',
#  'dunedin',
#  'yaan',
#  'arenapolis',
#  'dharchula',
#  'tvoroyri',
#  'tabiauea',
#  'altay',
#  'miquelon',
#  'hammerfest',
#  'hope',
#  'lang suan',
#  'samana',
#  'kavaratti',
#  'tucurui',
#  'providencia',
#  'latung',
#  'taketoyo',
#  'blackwater',
#  'katherine',
#  'padang',
#  'kapuskasing',
#  'namatanai',
#  'faanui',
#  'chernyshevskiy',
#  'visnes',
#  'galesong',
#  'cairns',
#  'samarai',
#  'moyale',
#  'vidim',
#  'coihaique',
#  'tautira',
#  'paranaiba',
#  'eirunepe',
#  'premia de mar',
#  'tutoia',
#  'shache',
#  'roros',
#  'bandar-e lengeh',
#  'chicama',
#  'amudat',
#  'puerto cortes',
#  'meulaboh',
#  'ayorou',
#  'beyneu',
#  'nouadhibou',
#  'puerto carreno',
#  'gondar',
#  'santa isabel',
#  'gravdal',
#  'itarema',
#  'catuday',
#  'plainfield',
#  'luwingu',
#  'chateaubelair',
#  'mamallapuram',
#  'esmeraldas',
#  'merauke',
#  'jackson',
#  'hamilton',
#  'moulins',
#  'kaberamaido',
#  'huazolotitlan',
#  'ilulissat',
#  'urfa',
#  'aljezur',
#  'vila',
#  'chuy',
#  'codrington',
#  'sydney',
#  'daru',
#  'vestmannaeyjar',
#  'rio verde de mato grosso',
#  'laupheim',
#  'hlobyne',
#  'punta de piedra',
#  'xuddur',
#  'bom jesus da lapa',
#  'kysyl-syr',
#  'bereznik',
#  'inuvik',
#  'sioux city',
#  'bonthe',
#  'karratha',
#  'terrace',
#  'cidreira',
#  'champerico',
#  'mareeba',
#  'araquari',
#  'falealupo',
#  'rawson',
#  'easton',
#  'chokurdakh',
#  'san policarpo',
#  'chippewa falls',
#  'sarkand',
#  'svetlaya',
#  'plettenberg bay',
#  'manokwari',
#  'lennoxtown',
#  'trat',
#  'ugoofaaru',
#  'shevchenkove',
#  'plouzane',
#  'marawi',
#  'port blair',
#  'santarem',
#  'klichka',
#  'chapais',
#  'kahului',
#  'teguldet',
#  'catamarca',
#  'praia da vitoria',
#  'bogorodskoye',
#  'wahran',
#  'tecoanapa',
#  'porbandar',
#  'north bend',
#  'tilichiki',
#  'mitsamiouli',
#  'rudiskes',
#  'mrirt',
#  'lavrentiya',
#  'tazovskiy',
#  'gore',
#  'tuxtepec',
#  'san francisco',
#  'kalmunai',
#  'tonantins',
#  'totma',
#  'blonduos',
#  'fort nelson',
#  'inongo',
#  'salamiyah',
#  'nipawin',
#  'miri',
#  'ahipara',
#  'baykit',
#  'at-bashi',
#  'maryanskaya',
#  'lochgilphead',
#  'pedasi',
#  'ahualulco',
#  'salta',
#  'apple valley',
#  'antofagasta',
#  'lodwar',
#  'ketchikan',
#  'tonj',
#  'udachnyy',
#  'indiana',
#  'parana',
#  'aklavik',
#  'lingao',
#  'kedrovyy',
#  'nome',
#  'gaya',
#  'alexandria',
#  'nelson bay',
#  'namibe',
#  'westport',
#  'hoa binh',
#  'verkhnyaya inta',
#  'montrose',
#  'zheleznodorozhnyy',
#  'dzhusaly',
#  'coahuayana',
#  'liseleje',
#  'kupang',
#  'sanda',
#  'ewa beach',
#  'mwense',
#  'lasa',
#  'bacungan',
#  'kalabo',
#  'zaoyang',
#  'sorong',
#  'satitoa',
#  'saint-leu',
#  'usinsk',
#  'sasovo',
#  'southbridge',
#  'khandyga',
#  'otane',
#  'tunduru',
#  'narsaq',
#  'richards bay',
#  'sokolo',
#  'otavi',
#  'paradwip',
#  'kobojango',
#  'honiara',
#  'fonte boa',
#  'egvekinot',
#  'burnie',
#  'naze',
#  'cururupu',
#  'korla',
#  'karamay',
#  'rognan',
#  'zhanaozen',
#  'bitung',
#  'rosarito',
#  'port hardy',
#  'bambamarca',
#  'mocambique',
#  'necochea',
#  'edgewater',
#  'goderich',
#  'moose factory',
#  'shelburne',
#  'iqaluit',
#  'vila do maio',
#  'kapit',
#  'francisco beltrao',
#  'basoko',
#  'newport',
#  'javanrud',
#  'susanville',
#  'peniche',
#  'am timan',
#  'mutsamudu',
#  'puerto madero',
#  'dicabisagan',
#  'kirkland lake',
#  'mafra',
#  'maragogi',
#  'chita',
#  'felipe carrillo puerto',
#  'karpogory',
#  'barsovo',
#  'salaga',
#  'mosjoen',
#  'gainesville',
#  'medicine hat',
#  'alice springs',
#  'bridlington',
#  'formosa do rio preto',
#  'saldus',
#  'novo aripuana',
#  'sorvag',
#  'muros',
#  'zwedru',
#  'christchurch',
#  'sur',
#  'mackay',
#  'temyasovo',
#  'livingstonia',
#  'teeli',
#  'umzimvubu',
#  'ilhabela',
#  'toora-khem',
#  'camacha',
#  'xai-xai',
#  'college',
#  'morgan city',
#  'malwan',
#  'zhigansk',
#  'valvedditturai',
#  'umm lajj',
#  'katsuura',
#  'hearst',
#  'high level',
#  'belmonte',
#  'santa cruz',
#  'chlorakas',
#  'jalu',
#  'ampanihy',
#  'yatou',
#  'dinguiraye',
#  'tual',
#  'inirida',
#  'taltal',
#  'severnoye',
#  'uyuni',
#  'mezen',
#  'rocha',
#  'korem',
#  'cullera',
#  'aranyosapati',
#  'kathmandu',
#  'paucartambo',
#  'berlevag',
#  'ambulu',
#  'aflu',
#  'sabha',
#  'wajima',
#  'kamenskoye',
#  'bathsheba',
#  'melito di porto salvo',
#  'krasnoborsk',
#  'marzuq',
#  'tura',
#  'shubarkuduk',
#  'tianpeng',
#  'salalah',
#  'vegueta',
#  'khuzhir',
#  'emmett',
#  'kadhan',
#  'mergui',
#  'cajamarca',
#  'faranah',
#  'churapcha',
#  'hovd',
#  'bankfoot',
#  'kruisfontein',
#  'angoche',
#  'geraldton',
#  'leshukonskoye',
#  'iranshahr',
#  'miles city',
#  'dombasle-sur-meurthe',
#  'west bay',
#  'harper',
#  'cap-aux-meules',
#  'flinders',
#  'la cruz']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#type(cities)

# %% [markdown]
# #### For reference - link to openweather api documentation: https://openweathermap.org/current

# %%
#Tested API calls on three citites list before trying with full list
#syntax: api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}

#Make api list into a smaller list
#test3=cities[0:3]
# test3

# %%
#API Info_cities list search url

base_url="http://api.openweathermap.org/data/2.5/weather?"

#Lists for dataframe
city_name_list=[]
cloudiness_list=[]
country_list=[]
date_list=[]
humidity_list=[]
lat_list=[]
lon_list=[]
max_temp_list=[]
windspeed_list=[]

#loop through test3
for city in cities:
    weather_response=requests.get(base_url + "appid=" + weather_api_key + "&q=" + city + "&units=Imperial")
    weather_data=weather_response.json()
    #pprint(weather_data)
    try:
        city_name_list.append(weather_data['name'])
        cloudiness_list.append(weather_data['clouds']['all'])
        country_list.append(weather_data['sys']['country'])
        date_list.append(weather_data['dt'])
        humidity_list.append(weather_data['main']['humidity'])
        lat_list.append(weather_data['coord']['lat'])
        lon_list.append(weather_data['coord']['lon'])
        max_temp_list.append(weather_data['main']['temp_max'])
        windspeed_list.append(weather_data['wind']['speed'])
        print(f"{city} found! Appending data.")
    except:
        print("City not found. No data appended.")
        pass
# Out:
# nikolskoye found! Appending data.
# jamestown found! Appending data.
# City not found. No data appended.
# butaritari found! Appending data.
# omboue found! Appending data.
# henties bay found! Appending data.
# gympie found! Appending data.
# busselton found! Appending data.
# havoysund found! Appending data.
# sola found! Appending data.
# avarua found! Appending data.
# rikitea found! Appending data.
# christchurch found! Appending data.
# norman wells found! Appending data.
# hithadhoo found! Appending data.
# severo-kurilsk found! Appending data.
# moramanga found! Appending data.
# port alfred found! Appending data.
# persianovskiy found! Appending data.
# longyearbyen found! Appending data.
# mineros found! Appending data.
# muros found! Appending data.
# qena found! Appending data.
# bardiyah found! Appending data.
# ponta do sol found! Appending data.
# bredasdorp found! Appending data.
# City not found. No data appended.
# City not found. No data appended.
# cape town found! Appending data.
# mahebourg found! Appending data.
# punta arenas found! Appending data.
# albany found! Appending data.
# ushuaia found! Appending data.
# petrolina de goias found! Appending data.
# new norfolk found! Appending data.
# torbay found! Appending data.
# kodiak found! Appending data.
# lagoa found! Appending data.
# provideniya found! Appending data.
# bluff found! Appending data.
# ogulin found! Appending data.
# benghazi found! Appending data.
# hasaki found! Appending data.
# hobyo found! Appending data.
# bandarbeyla found! Appending data.
# baoying found! Appending data.
# sibu found! Appending data.
# san patricio found! Appending data.
# kahului found! Appending data.
# City not found. No data appended.
# ancud found! Appending data.
# lazaro cardenas found! Appending data.
# den helder found! Appending data.
# mustasaari found! Appending data.
# kruisfontein found! Appending data.
# castro found! Appending data.
# suzun found! Appending data.
# port elizabeth found! Appending data.
# City not found. No data appended.
# City not found. No data appended.
# bogorodskoye found! Appending data.
# City not found. No data appended.
# cidreira found! Appending data.
# hermanus found! Appending data.
# san andres found! Appending data.
# okhotsk found! Appending data.
# vao found! Appending data.
# souillac found! Appending data.
# dikson found! Appending data.
# santa rosa found! Appending data.
# pevek found! Appending data.
# atuona found! Appending data.
# bajina basta found! Appending data.
# hobart found! Appending data.
# puerto ayora found! Appending data.
# vaini found! Appending data.
# japura found! Appending data.
# ponta delgada found! Appending data.
# tasiilaq found! Appending data.
# sobolevo found! Appending data.
# prince rupert found! Appending data.
# grand gaube found! Appending data.
# ilulissat found! Appending data.
# anloga found! Appending data.
# kapaa found! Appending data.
# seddon found! Appending data.
# korem found! Appending data.
# rio gallegos found! Appending data.
# City not found. No data appended.
# xinyang found! Appending data.
# kavieng found! Appending data.
# bubaque found! Appending data.
# pedasi found! Appending data.
# hearst found! Appending data.
# qinzhou found! Appending data.
# tiksi found! Appending data.
# cayenne found! Appending data.
# tigil found! Appending data.
# warrnambool found! Appending data.
# City not found. No data appended.
# bolobo found! Appending data.
# thompson found! Appending data.
# ambon found! Appending data.
# lexington found! Appending data.
# waterloo found! Appending data.
# terme found! Appending data.
# alvorada found! Appending data.
# lavrentiya found! Appending data.
# dunedin found! Appending data.
# City not found. No data appended.
# sao filipe found! Appending data.
# kenai found! Appending data.
# padang found! Appending data.
# bagdarin found! Appending data.
# kodinsk found! Appending data.
# santarem found! Appending data.
# mezhgorye found! Appending data.
# roebourne found! Appending data.
# dongning found! Appending data.
# pisco found! Appending data.
# ebolowa found! Appending data.
# port pirie found! Appending data.
# aklavik found! Appending data.
# gizo found! Appending data.
# luangwa found! Appending data.
# ormara found! Appending data.
# canutama found! Appending data.
# mikumi found! Appending data.
# sungaipenuh found! Appending data.
# tiarei found! Appending data.

# %%
#pprint(weather_data)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Display dataframe
weather_df=pd.DataFrame({
    "City Name": city_name_list,
    "Cloudiness": cloudiness_list,
    "Country": country_list,
    "Date": date_list,
    "Humidity": humidity_list,
    "Lat": lat_list,
    "Lng": lon_list,
    "Max Temp": max_temp_list,
    "Windspeed": windspeed_list    
})
weather_df
# Out:
#                    City Name  Cloudiness Country        Date  Humidity  \
# 0                 Nikolskoye          75      RU  1611994568        93
# 1                  Jamestown          90      US  1611994568        86
# 2                 Butaritari         100      KI  1611994509        77
# 3                     Omboué          81      GA  1611994569        82
# 4                Henties Bay          98      NA  1611994569        80
# 5                     Gympie          34      AU  1611994284        81
# 6                  Busselton           0      AU  1611994570        27
# 7                  Havøysund          90      NO  1611994570        80
# 8                       Sola         100      VU  1611994570        82
# 9                     Avarua          99      CK  1611994571        89
# 10                   Rikitea           7      PF  1611994571        75
# 11              Christchurch           0      NZ  1611994426        67
# 12              Norman Wells          75      CA  1611994572        75
# 13                 Hithadhoo           9      MV  1611994572        77
# 14           Severo-Kuril'sk         100      RU  1611994572        92
# 15                 Moramanga          17      MG  1611994573        51
# 16               Port Alfred          66      ZA  1611994573        68
# 17             Persianovskiy          75      RU  1611994573        87
# 18              Longyearbyen          20      SJ  1611994574        50
# 19                   Mineros          90      BO  1611994574        94
# 20                     Muros          56      ES  1611994574        85
# 21                      Qena           0      EG  1611994574        62
# 22               Al Bardīyah           0      LY  1611994574        61
# 23              Ponta do Sol          29      PT  1611994575        90
# 24                Bredasdorp           3      ZA  1611994575        66
# 25                 Cape Town          75      ZA  1611994498        50
# 26                 Mahébourg          75      MU  1611994576        66
# 27              Punta Arenas          40      CL  1611994287        76
# 28                    Albany           0      US  1611994447        77
# 29                   Ushuaia          40      AR  1611994521        81
# ..                       ...         ...     ...         ...       ...
# 532    Navalmoral de la Mata          66      ES  1611994715        88
# 533                 Pucallpa         100      PE  1611994716        97
# 534    Los Llanos de Aridane          40      ES  1611994716        82
# 535                 Marshall           1      US  1611994716        60
# 536                   Mumbai           0      IN  1611994641        29
# 537                  Lixouri          20      GR  1611994717        67
# 538                  Salinas           1      US  1611994548        87
# 539                    Kathu          20      TH  1611994717        51
# 540                     Brae          40      GB  1611994717        69
# 541                  Dunedin          38      NZ  1611994717        75
# 542               São Filipe          95      CV  1611994718        59
# 543                    Kenai          90      US  1611994718        85
# 544                   Padang          40      ID  1611994718        74
# 545                 Bagdarin          98      RU  1611994718        81
# 546                  Kodinsk          79      RU  1611994719        80
# 547                 Santarém          40      BR  1611994556        89
# 553 -33.1833  138.0167     71.60      24.16
# 554  68.2191 -135.0107    -29.20       2.80
# 555  -8.1030  156.8419     84.65      17.83
# 556 -15.6167   30.4167     74.77       2.08
# 557  25.2088   64.6357     69.75       5.44
# 558  -6.5339  -64.3831     72.75       1.86
# 559  -7.4041   36.9831     72.81       3.42
# 560  -2.0833  101.3833     69.26       2.28
# 561 -17.5333 -149.3333     80.60       3.44
#
# [562 rows x 9 columns]

# %%
#export to csv
weather_df.to_csv('output_data/cities.csv', header=True, index=True, index_label='City Number')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  562.000000  5.620000e+02  562.000000  562.000000  562.000000
# mean    52.115658  1.611995e+09   72.361210   18.518592   19.624952
# std     39.990540  7.062665e+01   21.260194   33.973491   91.201899
# min      0.000000  1.611994e+09   10.000000  -54.800000 -175.200000
# 25%      6.000000  1.611995e+09   62.000000   -9.856700  -63.216650
# 50%     56.500000  1.611995e+09   78.000000   20.682300   25.118250
# 75%     90.000000  1.611995e+09   88.000000   48.054125  101.302925
# max    100.000000  1.611995e+09  100.000000   78.218600  179.316700
#
#          Max Temp   Windspeed
# count  562.000000  562.000000
# mean    50.623648    8.668007
# std     33.666576    6.119147
# min    -43.910000    0.160000
# 25%     30.397500    3.600000
# 50%     62.600000    7.060000
# 75%     77.000000   12.322500
# max     98.620000   30.800000

# %%
weather_df.loc[weather_df['Humidity']>100,:] #Confirms there are no cities with humidity >100%
# Out:
# Empty DataFrame
# Columns: [City Name, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Windspeed]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
# NA because there are no cities with humidity over 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# NA because a new dataframe is not needed - using same dataframe (weather_df)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
weather_df.head(1)
# Out:
#     City Name  Cloudiness Country        Date  Humidity      Lat      Lng  \
# 0  Nikolskoye          75      RU  1611994568        93  59.7035  30.7861
#
#    Max Temp  Windspeed
# 0      30.2       8.95

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build Scatter plot
plt.figure(figsize=(13,9))
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], marker="o", c="purple", s=30)
plt.title("City Latitude vs. Max Temp (01/28/2020)", fontsize=20, y=1.02)
plt.ylabel("Max Temp (Fahrenheit)", fontsize=15, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Lat_vs_Temp.png')

# Show plot
plt.show()

# %% [markdown]
# ### Observations of Latitude vs. Temperature:
# #### This chart shows latitude vs. max temperature of all the cities included in the dataset. The following observations can be made:
# - The greatest average max temperature appears to be at the equator.
# - The majority of cities in the dataset are north of the equator, or in the Northern Hemisphere.
# - The higher that latitude, the colder it appears to be.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build Scatter plot
plt.figure(figsize=(13,9))
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker="o", c="purple", s=30)
plt.title("City Latitude vs. Humidity (01/28/2020)", fontsize=20, y=1.02)
plt.ylabel("Humidity (%)", fontsize=15, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)


# Save figure to .png
plt.savefig('output_data/Lat_vs_Humidity.png')

# Show plot
plt.show()

# %% [markdown]
# ### Observations of Latitude vs. Humidity:
# #### This chart shows latitude vs. humidity of all the cities included in the dataset. The following observations can be made:
# - There appears to be a greater % of humidity at the equator.
# - In the northern parts of the Northern Hemisphere, there appears to be a rise in humidity.
# - It seems the minimum humidity levels are clusterd around -20 and 20 degrees latitude. The area between the two tropics is high humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build Scatter plot
plt.figure(figsize=(13,9))
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], marker="o", c="purple", s=30)
plt.title("City Latitude vs. Cloudiness (01/28/2020)", fontsize=20, y=1.02)
plt.ylabel("Cloudiness (%)", fontsize=15, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Lat_vs_Cloudiness.png')

# Show plot
plt.show()

# %% [markdown]
# ### Observations of Latitude vs. Cloudiness:
# #### This chart shows latitude vs. cloudiness of all the cities included in the dataset. The following observations can be made:
# - There does not seem to be a clear correlation between latitude and cloudiness.
# - It seems that clouds are consistently disbursed among regions.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build Scatter plot
plt.figure(figsize=(13,9))
plt.scatter(weather_df['Lat'], weather_df['Windspeed'], marker="o", c="purple", s=30)
plt.title("City Latitude vs. Wind Speed (01/28/2020)", fontsize=20, y=1.02)
plt.ylabel("Wind Speed (mph)", fontsize=15, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Lat_vs_Windspeed.png')

# Show plot
plt.show()

# %% [markdown]
# ### Observations of Latitude vs. Wind Speed:
# #### This chart shows latitude vs. wind speed of all the cities included in the dataset. The following observations can be made:
# - Not many wind speeds are greater than 20mph.
# - Wind speed appears to be evenly dispersed over all latitudes.

# %% [markdown]
# ## Linear Regression

# %%
weather_df.head(1)
# Out:
#     City Name  Cloudiness Country        Date  Humidity      Lat      Lng  \
# 0  Nikolskoye          75      RU  1611994568        93  59.7035  30.7861
#
#    Max Temp  Windspeed
# 0      30.2       8.95

# %%
# break apart weather_df to one df for northern hemisphere and one for southern hemisphere

nh_df=weather_df.loc[weather_df['Lat']>=0,:]
#nh_df.describe()
sh_df=weather_df.loc[weather_df['Lat']<0,:]
#sh_df.describe()

# %% [markdown]
# ###  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build Scatter plot
x_values=nh_df['Lat']
y_values=nh_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values * slope + intercept
line_eq= "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(13,9))
plt.scatter(x_values, y_values, marker="o", c="purple", s=30)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(6,10), fontsize=20, color='red')
plt.title("Northern Hemisphere - Max Temp vs Latitude Linear Regression (01/29/2020)", fontsize=18, y=1.02)
plt.ylabel("Max Temp (Fahrenheit)", fontsize=15, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Line_Regress_NH_Lat_vs_Temp.png')

# Show plot
plt.show()

# %% [markdown]
# ### The following is modeled in the linear regression above:
# - A negative correlation.
# - The negative correlation means that as latitude increases, the max temperature decreases at a consistent rate.
# - For every increase in one degree of latitude, the max temperature decreases by 1.52 degrees.
# - When latitude is 0 degrees, the model predicts the max temperature to be approx. 98 degrees F.

# %% [markdown]
# ###  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build Scatter plot
x_values=sh_df['Lat']
y_values=sh_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values * slope + intercept
line_eq= "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(13,9))
plt.scatter(x_values, y_values, marker="o", c="purple", s=30)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-25,52), fontsize=20, color='red')
plt.title("Southern Hemisphere - Max Temp vs Latitude Linear Regression (01/29/2020)", fontsize=18, y=1.02)
plt.ylabel("Max Temp (Fahrenheit)", fontsize=15, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Line_Regress_SH_Lat_vs_Temp.png')

# Show plot
plt.show()

# %% [markdown]
# ### The following is modeled in the linear regression above:
# - A negative correlation.
# - Even though the slope is positive, the correlation is negative because the latitude values are negative numbers.
# - As latitude increases to the south by 1 degree, max temperature decreases by .45 degrees F.
# - At a latitude of 0, this model predicts a max temperature of approx. 83 degrees F.

# %% [markdown]
# ###  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build Scatter plot
x_values=nh_df['Lat']
y_values=nh_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values * slope + intercept
line_eq= "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(13,9))
plt.scatter(x_values, y_values, marker="o", c="purple", s=30)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(58,21), fontsize=20, color='red')
plt.title("Northern Hemisphere - Humidity vs Latitude Linear Regression (01/29/2020)", fontsize=18, y=1.02)
plt.ylabel("Humidity (%)", fontsize=15, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Line_Regress_NH_Lat_vs_Humidity.png')

# Show plot
plt.show()

# %% [markdown]
# ### The following is modeled in the linear regression above:
# - No correlation.
# - A liner regression does not provide the best description of this dataset because humidity values seem to be high at the equator, decrease towards the tropic, then increasing again north of the tropic.

# %% [markdown]
# ###  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build Scatter plot
x_values=sh_df['Lat']
y_values=sh_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values * slope + intercept
line_eq= "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(13,9))
plt.scatter(x_values, y_values, marker="o", c="purple", s=30)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-18,50), fontsize=20, color='red')
plt.title("Southern Hemisphere - Humidity vs Latitude Linear Regression (01/29/2020)", fontsize=18, y=1.02)
plt.ylabel("Humidity (%)", fontsize=15, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Line_Regress_SH_Lat_vs_Humidity.png')

# Show plot
plt.show()

# %% [markdown]
# ### The following is modeled in the linear regression above:
# - No correlation.
# - A liner regression does not provide the best description of this dataset.

# %% [markdown]
# ###  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Build Scatter plot
x_values=nh_df['Lat']
y_values=nh_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values * slope + intercept
line_eq= "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(13,9))
plt.scatter(x_values, y_values, marker="o", c="purple", s=30)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(60,50), fontsize=20, color='red')
plt.title("Northern Hemisphere - Cloudiness vs Latitude Linear Regression (01/29/2020)", fontsize=18, y=1.02)
plt.ylabel("Cloudiness (%)", fontsize=20, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Line_Regress_NH_Lat_vs_Cloudiness.png')

# Show plot
plt.show()

# %% [markdown]
# ### The following is modeled in the linear regression above:
# - There is no correlation between latitude and cloudiness in the northern hemisphere.

# %% [markdown]
# ###  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Build Scatter plot
x_values=sh_df['Lat']
y_values=sh_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values * slope + intercept
line_eq= "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(13,9))
plt.scatter(x_values, y_values, marker="o", c="purple", s=30)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-55,50), fontsize=20, color='red')
plt.title("Southern Hemisphere - Cloudiness vs Latitude Linear Regression (01/29/2020)", fontsize=18, y=1.02)
plt.ylabel("Cloudiness (%)", fontsize=20, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Line_Regress_SH_Lat_vs_Cloudiness.png')

# Show plot
plt.show()

# %% [markdown]
# ### The following is modeled in the linear regression above:
# - There is no correlation between latitude and cloudiness in the southern hemisphere.

# %% [markdown]
# ###  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Build Scatter plot
x_values=nh_df['Lat']
y_values=nh_df['Windspeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values * slope + intercept
line_eq= "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(13,9))
plt.scatter(x_values, y_values, marker="o", c="purple", s=30)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(5,26), fontsize=20, color='red')
plt.title("Northern Hemisphere - Wind Speed vs Latitude Linear Regression (01/29/2020)", fontsize=18, y=1.02)
plt.ylabel("Wind Speed (mph)", fontsize=20, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Line_Regress_NH_Lat_vs_Windspeed.png')

# Show plot
plt.show()

# %% [markdown]
# ### The following is modeled in the linear regression above:
# - This regression has very minimal slope, therefore, the model predicts that wind speed is, on average, the same no matter where you are in latitude within the northern hemisphere.
# - The average wind speed is approx. 10mph across the northern hemisphere.

# %% [markdown]
# ###  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Build Scatter plot
x_values=sh_df['Lat']
y_values=sh_df['Windspeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values= x_values * slope + intercept
line_eq= "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(13,9))
plt.scatter(x_values, y_values, marker="o", c="purple", s=30)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-52,16), fontsize=20, color='red')
plt.title("Southern Hemisphere - Wind Speed vs Latitude Linear Regression (01/29/2020)", fontsize=18, y=1.02)
plt.ylabel("Wind Speed (mph)", fontsize=20, labelpad=15)
plt.xlabel("Latitude", fontsize=15, labelpad=15)
plt.tick_params(labelsize=12, pad=8)
plt.grid(True)

# Save figure to .png
plt.savefig('output_data/Line_Regress_SH_Lat_vs_Windspeed.png')

# Show plot
plt.show()

# %% [markdown]
# ### The following is modeled in the linear regression above:
# - This regression has almost no slope, meaning wind speed is about the same across the southern hemisphere.
# - The average windspeed across the southern hemisphere is approx. 8 mph.
